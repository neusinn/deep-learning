# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:40, 783KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6952 0.0844 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6063 0.0794 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5228 0.0790 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5825 0.0783 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5190 0.0788 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4996 0.0785 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5482 0.0790 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5309 0.0800 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4735 0.0814 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4289 0.0827 sec/batch
# Nearest to is: boasian, forastero, requirements, pomeranian, kahlert, dect, haven, parable,
# Nearest to two: collide, sacd, xxxix, thwomps, encountering, manifested, ila, monopropellant,
# Nearest to people: vive, emissaries, heuvelmans, pigments, poorest, saipan, blocker, grimm,
# Nearest to united: grossman, seedy, fiorentina, whitewashing, mutilated, largely, hypomanic, henares,
# Nearest to by: tunnels, saltzman, lightly, dupin, cyprinus, manhattan, uninterrupted, create,
# Nearest to an: supernova, kali, morel, staunch, hakuin, chamonix, theatrically, horton,
# Nearest to most: trumped, railways, hardness, monopropellant, optimizing, deniability, gulags, rushed,
# Nearest to time: hesychasts, at, gunpowder, looked, designer, toronto, trafficking, maryland,
# Nearest to bible: lengthwise, atone, counties, naked, arrival, sells, pairs, succesor,
# Nearest to accepted: infinitives, whoever, trains, divergence, strafford, cordwainer, altered, davison,
# Nearest to except: focussed, kyd, candidates, savannas, swelling, vert, intonation, excl,
# Nearest to orthodox: thug, err, haughton, raeben, fashions, bilbo, yunus, fanzines,
# Nearest to bbc: rosencrantz, terrestris, pap, inflation, disguised, landings, eir, rollout,
# Nearest to dr: ugc, subspaces, sickly, karim, pamphlets, phallus, swordsman, liv,
# Nearest to something: rebuild, epidermis, hi, retention, sasquatch, dvi, mee, bhagavad,
# Nearest to troops: jellinek, indigenous, dominator, delilah, abodes, yukon, vascular, accede,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4779 0.0847 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4042 0.0848 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3675 0.0854 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2211 0.0858 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2180 0.0863 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1770 0.0866 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1288 0.0878 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0734 0.0869 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9964 0.0865 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9879 0.0871 sec/batch
# Nearest to is: requirements, wealth, latin, to, forastero, haven, the, matters,
# Nearest to two: collide, manifested, sacd, context, xxxix, narrative, minimum, calling,
# Nearest to people: vive, poorest, pigments, emissaries, limitation, sheep, saipan, blocker,
# Nearest to united: grossman, largely, play, seedy, fiorentina, chase, mutilated, accurate,
# Nearest to by: tunnels, create, saltzman, lightly, manhattan, dupin, play, india,
# Nearest to an: supernova, examples, kali, full, depending, morel, staunch, schedules,
# Nearest to most: hardness, long, railways, optimizing, addition, commission, trumped, hbp,
# Nearest to time: at, looked, gunpowder, trafficking, hesychasts, angle, designer, response,
# Nearest to bible: lengthwise, pairs, atone, making, sells, naked, counties, arrival,
# Nearest to accepted: altered, trains, infinitives, political, whoever, fall, divergence, landslide,
# Nearest to except: focussed, candidates, kyd, vert, swelling, robust, savannas, significantly,
# Nearest to orthodox: thug, noticed, err, haughton, armada, proudest, fashions, overused,
# Nearest to bbc: fishing, terrestris, inflation, landings, rosencrantz, disguised, rollout, stored,
# Nearest to dr: pamphlets, subspaces, ugc, sickly, conjoined, purposes, phallus, tortured,
# Nearest to something: rebuild, hi, retention, at, epidermis, admiralty, nationalistic, negative,
# Nearest to troops: indigenous, jellinek, yukon, dominator, violations, malcolm, vascular, specifies,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9274 0.0884 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9172 0.0877 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8897 0.0875 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8760 0.0876 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8294 0.0879 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8018 0.0880 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7989 0.0887 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7992 0.0879 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7875 0.0880 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7752 0.0883 sec/batch
# Nearest to is: requirements, wealth, boasian, forastero, haven, parable, understood, matters,
# Nearest to two: collide, nine, manifested, encountering, explains, calling, xxxix, sacd,
# Nearest to people: vive, poorest, pigments, emissaries, saipan, blocker, stellar, goalie,
# Nearest to united: grossman, largely, seedy, chase, fiorentina, mutilated, allegiance, play,
# Nearest to by: tunnels, lightly, saltzman, create, dupin, manhattan, play, uninterrupted,
# Nearest to an: supernova, staunch, morel, kali, full, lausanne, schedules, wit,
# Nearest to most: railways, optimizing, hardness, addition, long, commission, trumped, rushed,
# Nearest to time: gunpowder, trafficking, looked, angle, behavioral, at, designer, lieu,
# Nearest to bible: lengthwise, pairs, naked, arrival, counties, atone, sells, reduce,
# Nearest to accepted: whoever, cordwainer, divergence, political, faqs, altered, infinitives, trains,
# Nearest to except: focussed, candidates, kyd, robust, savannas, vert, swelling, spend,
# Nearest to orthodox: thug, haughton, regarded, fashions, noticed, armada, connotations, proudest,
# Nearest to bbc: inflation, fishing, landings, disguised, terrestris, nobelprize, resumed, rosencrantz,
# Nearest to dr: sickly, pamphlets, subspaces, ugc, intergovernmental, burns, conjoined, phallus,
# Nearest to something: admiralty, rebuild, hi, retention, epidermis, iterated, nationalistic, at,
# Nearest to troops: indigenous, violations, jellinek, yukon, specifies, dominator, homologues, saltzman,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7513 0.0893 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7866 0.0894 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7335 0.0898 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7270 0.0893 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7367 0.0902 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7224 0.0890 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6951 0.0893 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7116 0.0889 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7002 0.0892 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6898 0.0895 sec/batch
# Nearest to is: requirements, forastero, wealth, haven, parable, cache, boasian, dect,
# Nearest to two: nine, five, collide, three, seven, december, encountering, magnate,
# Nearest to people: vive, poorest, pigments, saipan, stellar, goalie, blocker, emissaries,
# Nearest to united: grossman, republic, largely, israeli, seedy, mutilated, fiorentina, forested,
# Nearest to by: tunnels, lightly, saltzman, create, dupin, mourning, manhattan, exiled,
# Nearest to an: supernova, morel, staunch, lausanne, bal, wit, tricky, horton,
# Nearest to most: railways, trumped, optimizing, hardness, long, addition, correspondents, commission,
# Nearest to time: gunpowder, trafficking, behavioral, lombardi, at, lieu, angle, hesychasts,
# Nearest to bible: lengthwise, atone, naked, pairs, arrival, mosque, counties, sells,
# Nearest to accepted: cordwainer, whoever, divergence, political, faqs, infinitives, altered, strafford,
# Nearest to except: focussed, candidates, kyd, robust, savannas, vert, swelling, intonation,
# Nearest to orthodox: haughton, thug, fashions, regarded, noticed, connotations, fanzines, signings,
# Nearest to bbc: inflation, landings, disguised, terrestris, fishing, rollout, rosencrantz, vet,
# Nearest to dr: sickly, ugc, pamphlets, intergovernmental, karim, phallus, subspaces, swordsman,
# Nearest to something: admiralty, hi, iterated, monsanto, epidermis, nationalistic, retention, craftsmen,
# Nearest to troops: indigenous, violations, homologues, yukon, azul, eagles, morris, jellinek,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6636 0.0902 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6792 0.0890 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6170 0.0898 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6025 0.0895 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6268 0.0891 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6624 0.0888 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5926 0.0649 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5271 0.0895 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5063 0.0890 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4906 0.0883 sec/batch
# Nearest to is: cache, boasian, forastero, requirements, parable, the, inflectional, dect,
# Nearest to two: five, nine, four, seven, three, december, zero, collide,
# Nearest to people: vive, poorest, pigments, saipan, emissaries, stellar, goalie, masterfully,
# Nearest to united: grossman, republic, seedy, south, affleck, mutilated, largely, israeli,
# Nearest to by: tunnels, saltzman, lightly, dupin, exiled, mourning, create, uninterrupted,
# Nearest to an: supernova, morel, lausanne, staunch, bal, toolbox, wit, kali,
# Nearest to most: trumped, railways, hardness, long, optimizing, correspondents, commission, deniability,
# Nearest to time: gunpowder, trafficking, behavioral, lombardi, at, lieu, looked, hesychasts,
# Nearest to bible: lengthwise, atone, mosque, naked, arrival, maynard, pairs, aravalli,
# Nearest to accepted: whoever, cordwainer, divergence, political, faqs, infinitives, altered, landslide,
# Nearest to except: focussed, savannas, kyd, robust, swelling, intonation, candidates, vert,
# Nearest to orthodox: haughton, fashions, thug, regarded, noticed, christian, religion, connotations,
# Nearest to bbc: landings, inflation, disguised, terrestris, rollout, rosencrantz, fishing, aut,
# Nearest to dr: sickly, ugc, pamphlets, swordsman, karim, intergovernmental, phallus, burns,
# Nearest to something: admiralty, iterated, monsanto, craftsmen, bhagavad, nationalistic, disunity, hi,
# Nearest to troops: indigenous, violations, homologues, azul, yukon, eagles, carthage, disaster,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5061 0.0895 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4638 0.0888 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4461 0.0894 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5326 0.0892 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5123 0.0890 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4561 0.0894 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4446 0.0896 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3897 0.0901 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4460 0.0904 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4353 0.0903 sec/batch
# Nearest to is: the, cache, a, forastero, inflectional, dimensions, separable, cells,
# Nearest to two: five, nine, three, december, four, zero, collide, seven,
# Nearest to people: poorest, vive, emissaries, saipan, pigments, ethnically, masterfully, dorado,
# Nearest to united: grossman, republic, affleck, south, seedy, israeli, nicaragua, cdb,
# Nearest to by: tunnels, saltzman, lightly, dupin, mourning, create, exiled, uninterrupted,
# Nearest to an: supernova, lausanne, morel, staunch, depending, hakuin, toolbox, kali,
# Nearest to most: trumped, railways, hardness, long, optimizing, deniability, phoebastria, correspondents,
# Nearest to time: gunpowder, lombardi, behavioral, at, angle, trafficking, dangerous, hesychasts,
# Nearest to bible: prophets, lengthwise, mosque, biblical, commentary, christian, divine, atone,
# Nearest to accepted: divergence, whoever, political, cordwainer, infinitives, faqs, benzodiazepines, landslide,
# Nearest to except: focussed, savannas, kyd, swelling, robust, vert, intonation, spend,
# Nearest to orthodox: christian, religion, haughton, regarded, fashions, connotations, christianity, imbued,
# Nearest to bbc: disguised, landings, terrestris, rosencrantz, shelled, inflation, rollout, fatalities,
# Nearest to dr: sickly, ugc, karim, pamphlets, swordsman, phallus, intergovernmental, hbo,
# Nearest to something: admiralty, iterated, craftsmen, sasquatch, monsanto, pulley, mee, conceptions,
# Nearest to troops: violations, indigenous, azul, carthage, homologues, yukon, disaster, zoran,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4272 0.0912 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4185 0.0896 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4541 0.0896 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3860 0.0905 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3986 0.0898 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4380 0.0891 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4003 0.0899 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3624 0.0894 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4032 0.0895 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3861 0.0894 sec/batch
# Nearest to is: the, separable, boasian, parentheses, dect, cache, dimensions, forastero,
# Nearest to two: five, nine, three, four, zero, seven, december, collide,
# Nearest to people: poorest, vive, homographs, emissaries, saipan, ethnically, noir, goalie,
# Nearest to united: affleck, grossman, republic, nicaragua, south, cdb, seedy, hanko,
# Nearest to by: tunnels, lightly, saltzman, create, mourning, uninterrupted, stalled, houses,
# Nearest to an: supernova, morel, lausanne, staunch, toolbox, depending, kali, hakuin,
# Nearest to most: trumped, long, hardness, railways, deniability, optimizing, correspondents, addition,
# Nearest to time: lombardi, gunpowder, at, lieu, trafficking, angle, behavioral, fridays,
# Nearest to bible: prophets, biblical, lengthwise, commentary, atone, mosque, divine, christian,
# Nearest to accepted: divergence, political, cordwainer, whoever, infinitives, faqs, benzodiazepines, fuego,
# Nearest to except: focussed, savannas, kyd, swelling, robust, vert, spend, intonation,
# Nearest to orthodox: christian, religion, haughton, christianity, church, regarded, prayer, imbued,
# Nearest to bbc: disguised, rosencrantz, landings, terrestris, rollout, shelled, aut, vet,
# Nearest to dr: sickly, ugc, karim, jill, swordsman, pamphlets, burns, phallus,
# Nearest to something: admiralty, iterated, conceptions, sasquatch, obscured, pulley, craftsmen, disunity,
# Nearest to troops: violations, indigenous, azul, carthage, homologues, zoran, procured, yukon,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3657 0.0898 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3721 0.0886 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3353 0.0891 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3824 0.0892 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3963 0.0891 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3573 0.0889 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3590 0.0893 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3821 0.0893 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3736 0.0902 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3283 0.0899 sec/batch
# Nearest to is: the, separable, interchangeably, haven, a, inflectional, dedekind, prayer,
# Nearest to two: five, nine, three, four, zero, seven, december, one,
# Nearest to people: poorest, emissaries, homographs, vive, ethnically, pigments, noir, descendants,
# Nearest to united: affleck, nicaragua, grossman, republic, hanko, south, seedy, comecon,
# Nearest to by: tunnels, saltzman, lightly, create, uninterrupted, as, houses, stalled,
# Nearest to an: supernova, lausanne, morel, staunch, ackroyd, irrespective, yeah, disjoint,
# Nearest to most: trumped, long, correspondents, railways, deniability, commission, gulags, optimizing,
# Nearest to time: lombardi, gunpowder, at, lieu, leveraged, hizbullah, behavioral, objectives,
# Nearest to bible: prophets, biblical, commentary, lengthwise, christian, atone, mosque, worldly,
# Nearest to accepted: divergence, political, cordwainer, whoever, faqs, infinitives, benzodiazepines, implicit,
# Nearest to except: focussed, robust, savannas, vert, swelling, spend, kyd, excl,
# Nearest to orthodox: christian, religion, haughton, christianity, heretical, prayer, imbued, persecution,
# Nearest to bbc: rosencrantz, terrestris, disguised, landings, rollout, aut, plow, shelled,
# Nearest to dr: ugc, sickly, karim, swordsman, jill, pamphlets, burns, phallus,
# Nearest to something: conceptions, admiralty, iterated, sasquatch, bhagavad, monsanto, disunity, pulley,
# Nearest to troops: violations, indigenous, azul, carthage, riots, war, disaster, procured,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3478 0.0914 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2732 0.0897 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3453 0.0890 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3681 0.0890 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3621 0.0891 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3088 0.0897 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2931 0.0894 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3319 0.0891 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2367 0.0899 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2923 0.0902 sec/batch
# Nearest to is: the, haven, interchangeably, separable, parentheses, a, dect, dedekind,
# Nearest to two: five, nine, zero, three, four, seven, one, december,
# Nearest to people: poorest, vive, saipan, emissaries, homographs, ethnically, descendants, noir,
# Nearest to united: affleck, grossman, nicaragua, seedy, tsarist, republic, comecon, npd,
# Nearest to by: tunnels, lightly, saltzman, create, councillors, exiled, uninterrupted, stalled,
# Nearest to an: supernova, lausanne, staunch, morel, ackroyd, bal, horton, iguanodon,
# Nearest to most: trumped, long, correspondents, railways, gulags, deniability, optimizing, commission,
# Nearest to time: lombardi, gunpowder, at, angle, looked, hizbullah, leveraged, lieu,
# Nearest to bible: prophets, biblical, commentary, lengthwise, atone, mosque, christian, translation,
# Nearest to accepted: political, divergence, cordwainer, faqs, whoever, infinitives, benzodiazepines, strafford,
# Nearest to except: focussed, robust, savannas, swelling, vert, kyd, spend, unsettled,
# Nearest to orthodox: christian, religion, haughton, heretical, discourage, imbued, persecution, hasdai,
# Nearest to bbc: rosencrantz, terrestris, disguised, landings, rollout, sunset, aut, hardback,
# Nearest to dr: karim, sickly, ugc, jill, swordsman, blige, burns, liv,
# Nearest to something: conceptions, iterated, hopefully, craftsmen, disunity, bhagavad, neurophysiological, monsanto,
# Nearest to troops: violations, azul, war, carthage, indigenous, disaster, riots, procured,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2899 0.0901 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2989 0.0890 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3235 0.0398 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2595 0.0894 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2183 0.0888 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2290 0.0886 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2211 0.0888 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2026 0.0885 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2092 0.0893 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1578 0.0890 sec/batch
# Nearest to is: the, parentheses, haven, forastero, restaurants, dect, a, separable,
# Nearest to two: five, nine, zero, three, four, seven, one, december,
# Nearest to people: poorest, homographs, vive, gediminas, saipan, emissaries, descendants, ethnically,
# Nearest to united: affleck, seedy, grossman, npd, comecon, nicaragua, cards, tsarist,
# Nearest to by: tunnels, saltzman, lightly, stalled, exiled, uninterrupted, dupin, houses,
# Nearest to an: supernova, lausanne, morel, ackroyd, staunch, disjoint, nicephorus, bal,
# Nearest to most: railways, trumped, long, deniability, in, drains, phoebastria, grained,
# Nearest to time: at, lombardi, gunpowder, hizbullah, looked, ajaigarh, lieu, angle,
# Nearest to bible: biblical, prophets, commentary, lengthwise, atone, tanakh, christian, mosque,
# Nearest to accepted: divergence, political, cordwainer, faqs, whoever, infinitives, benzodiazepines, oligarchic,
# Nearest to except: robust, focussed, savannas, spend, swelling, vert, kyd, intonation,
# Nearest to orthodox: christian, haughton, religion, discourage, hasdai, yunus, christianity, imbued,
# Nearest to bbc: rosencrantz, terrestris, disguised, rollout, landings, plow, aut, premiered,
# Nearest to dr: karim, ugc, sickly, jill, swordsman, blige, burns, conjoined,
# Nearest to something: conceptions, iterated, enchantment, craftsmen, monsanto, admiralty, conversation, kelley,
# Nearest to troops: violations, riots, azul, disaster, carthage, war, tactics, zoran,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2387 0.0896 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2069 0.0892 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2144 0.0897 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1169 0.0900 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1727 0.0903 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1840 0.0901 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1457 0.0902 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1743 0.0900 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2062 0.0898 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1741 0.0901 sec/batch
# Nearest to is: the, parentheses, a, separable, dect, forastero, polyatomic, interchangeably,
# Nearest to two: five, zero, nine, four, three, seven, one, december,
# Nearest to people: poorest, vive, homographs, descendants, gediminas, noir, amphibians, emissaries,
# Nearest to united: affleck, seedy, comecon, grossman, nicaragua, npd, jurors, hanko,
# Nearest to by: tunnels, stalled, lightly, create, uninterrupted, saltzman, dupin, syst,
# Nearest to an: supernova, lausanne, ackroyd, disjoint, amputation, staunch, recapitulation, morel,
# Nearest to most: long, trumped, grained, in, optimizing, railways, educates, phoebastria,
# Nearest to time: at, gunpowder, lombardi, angle, leveraged, ajaigarh, hizbullah, inertia,
# Nearest to bible: biblical, prophets, lengthwise, atone, commentary, tanakh, book, mosque,
# Nearest to accepted: divergence, cordwainer, political, faqs, infinitives, psychedelics, oligarchic, benzodiazepines,
# Nearest to except: robust, focussed, spend, vert, kyd, savannas, swelling, futurians,
# Nearest to orthodox: christian, religion, haughton, hasdai, imbued, discourage, heretical, christianity,
# Nearest to bbc: rosencrantz, terrestris, premiered, embarking, disguised, plow, rollout, stalks,
# Nearest to dr: karim, ugc, jill, swordsman, sickly, answering, conjoined, novelty,
# Nearest to something: conceptions, iterated, enchantment, craftsmen, conversation, lorids, broadcasts, admiralty,
# Nearest to troops: violations, carthage, riots, tactics, disaster, azul, war, zoran,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1847 0.0906 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2118 0.0892 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1710 0.0892 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1510 0.0901 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1942 0.0896 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1869 0.0892 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2130 0.0890 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1665 0.0884 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1223 0.0891 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1696 0.0890 sec/batch
# Nearest to is: the, a, separable, parentheses, anaximander, dect, haven, interchangeably,
# Nearest to two: five, zero, four, three, nine, one, seven, december,
# Nearest to people: poorest, descendants, homographs, emissaries, vive, gediminas, ethnically, noir,
# Nearest to united: affleck, seedy, comecon, nicaragua, npd, grossman, cdb, jurors,
# Nearest to by: tunnels, saltzman, uninterrupted, stalled, create, lightly, marrying, as,
# Nearest to an: supernova, lausanne, ackroyd, staunch, exaggeration, morel, representable, disjoint,
# Nearest to most: grained, trumped, in, correspondents, long, deniability, drains, monopropellant,
# Nearest to time: at, lombardi, gunpowder, lieu, inertia, hizbullah, leveraged, charitable,
# Nearest to bible: biblical, prophets, lengthwise, atone, commentary, tanakh, catechism, translation,
# Nearest to accepted: divergence, cordwainer, political, faqs, strafford, infinitives, benzodiazepines, implicit,
# Nearest to except: focussed, robust, spend, vert, savannas, kyd, can, unsettled,
# Nearest to orthodox: christian, haughton, yunus, imbued, hasdai, raeben, ecb, religion,
# Nearest to bbc: rosencrantz, cnn, premiered, terrestris, disguised, embarking, plow, newspapers,
# Nearest to dr: karim, jill, answering, hbo, ugc, conjoined, burns, blige,
# Nearest to something: iterated, enchantment, conceptions, lorids, craftsmen, epidermis, broadcasts, bhagavad,
# Nearest to troops: violations, carthage, azul, riots, tactics, accede, zoran, disaster,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1795 0.0900 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1513 0.0891 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1505 0.0890 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2039 0.0893 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1341 0.0899 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1324 0.0896 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1584 0.0899 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1110 0.0900 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1884 0.0892 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2121 0.0894 sec/batch
# Nearest to is: dect, anaximander, haven, prayer, the, a, parentheses, interchangeably,
# Nearest to two: five, zero, nine, four, three, one, seven, december,
# Nearest to people: poorest, noir, descendants, gediminas, homographs, emissaries, saipan, graziani,
# Nearest to united: affleck, seedy, nicaragua, grossman, comecon, cdb, npd, consulate,
# Nearest to by: uninterrupted, stalled, councillors, saltzman, marrying, tunnels, lightly, aces,
# Nearest to an: lausanne, supernova, ackroyd, morel, nobleman, staunch, nicephorus, irrespective,
# Nearest to most: trumped, grained, railways, correspondents, long, in, amigaos, deniability,
# Nearest to time: at, lombardi, gunpowder, leveraged, charitable, hates, looked, inertia,
# Nearest to bible: lengthwise, atone, biblical, prophets, goode, commentary, translation, tanakh,
# Nearest to accepted: cordwainer, divergence, political, strafford, oligarchic, faqs, davison, claimant,
# Nearest to except: focussed, robust, spend, vert, unsettled, savannas, kyd, can,
# Nearest to orthodox: haughton, christian, hasdai, imbued, yunus, raeben, discourage, scriptural,
# Nearest to bbc: rosencrantz, cnn, embarking, terrestris, premiered, sunset, newspapers, plow,
# Nearest to dr: karim, swordsman, answering, hbo, jill, blige, conjoined, roeg,
# Nearest to something: iterated, enchantment, conceptions, lorids, epidermis, broadcasts, kelley, bhagavad,
# Nearest to troops: violations, carthage, tactics, azul, bombardment, disaster, accede, ripuarian,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2440 0.0905 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1311 0.0891 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1373 0.0888 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1553 0.0890 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0554 0.0894 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1695 0.0894 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1533 0.0892 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1410 0.0893 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1784 0.0148 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1378 0.0888 sec/batch
# Nearest to is: the, a, parentheses, dect, haven, anaximander, opts, interchangeably,
# Nearest to two: five, zero, nine, four, three, one, seven, december,
# Nearest to people: poorest, noir, gediminas, amphibians, descendants, emissaries, population, fertility,
# Nearest to united: affleck, seedy, nicaragua, comecon, grossman, npd, jurors, sharqi,
# Nearest to by: uninterrupted, saltzman, stalled, tunnels, create, syst, marrying, lightly,
# Nearest to an: supernova, lausanne, disjoint, representable, insulinotherapy, deployed, ackroyd, nobleman,
# Nearest to most: in, grained, trumped, railways, many, drains, long, amigaos,
# Nearest to time: at, lombardi, gunpowder, looked, hizbullah, angle, hates, ajaigarh,
# Nearest to bible: lengthwise, biblical, atone, prophets, goode, commentary, tanakh, mosque,
# Nearest to accepted: cordwainer, divergence, political, faqs, oligarchic, strafford, davison, whoever,
# Nearest to except: focussed, robust, spend, vert, can, savannas, kyd, goes,
# Nearest to orthodox: haughton, christian, err, hasdai, yunus, imbued, raeben, fanzines,
# Nearest to bbc: rosencrantz, cnn, embarking, terrestris, sunset, newspapers, premiered, aut,
# Nearest to dr: karim, answering, blige, swordsman, ugc, ponty, colo, freiburg,
# Nearest to something: enchantment, iterated, lorids, conceptions, conversation, bhagavad, neurophysiological, realize,
# Nearest to troops: violations, carthage, tactics, accede, bombardment, zoran, azul, ripuarian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0445 0.0909 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0609 0.0894 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0856 0.0882 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0653 0.0884 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0930 0.0891 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0290 0.0885 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1123 0.0886 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0597 0.0892 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1163 0.0897 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0429 0.0898 sec/batch
# Nearest to is: the, a, parentheses, dect, prayer, inflectional, all, polyatomic,
# Nearest to two: five, zero, three, four, nine, one, seven, december,
# Nearest to people: poorest, descendants, amphibians, population, homographs, gediminas, noir, emissaries,
# Nearest to united: affleck, seedy, comecon, nicaragua, sharqi, jurors, npd, ryukyu,
# Nearest to by: tunnels, uninterrupted, stalled, marrying, saltzman, syst, lightly, as,
# Nearest to an: supernova, lausanne, nobleman, disjoint, representable, deployed, ackroyd, morel,
# Nearest to most: in, grained, railways, drains, many, amigaos, trumped, extend,
# Nearest to time: at, lombardi, gunpowder, ajaigarh, angle, halt, a, looked,
# Nearest to bible: biblical, lengthwise, prophets, tanakh, atone, commentary, goode, book,
# Nearest to accepted: divergence, cordwainer, political, oligarchic, faqs, strafford, whoever, davison,
# Nearest to except: robust, focussed, spend, vert, kyd, can, if, goes,
# Nearest to orthodox: christian, haughton, err, hasdai, imbued, yunus, fanzines, armada,
# Nearest to bbc: rosencrantz, cnn, broadcasting, embarking, newspapers, itv, sunset, terrestris,
# Nearest to dr: answering, karim, intergovernmental, swordsman, accidental, hitchens, deride, hbo,
# Nearest to something: enchantment, iterated, lorids, conceptions, broadcasts, conversation, craftsmen, occidentalis,
# Nearest to troops: violations, tactics, bombardment, carthage, ripuarian, accede, azul, zoran,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0296 0.0914 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0243 0.0905 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9994 0.0901 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0650 0.0908 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0677 0.0906 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0759 0.0903 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0763 0.0899 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1043 0.0892 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0684 0.0893 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0263 0.0895 sec/batch
# Nearest to is: a, the, all, unique, separable, parentheses, vectors, an,
# Nearest to two: five, zero, three, four, nine, one, seven, december,
# Nearest to people: poorest, descendants, amphibians, homographs, population, gediminas, emissaries, lice,
# Nearest to united: affleck, seedy, comecon, jurors, npd, nicaragua, sharqi, mcdermott,
# Nearest to by: which, uninterrupted, tunnels, marrying, as, stalled, icy, saltzman,
# Nearest to an: supernova, disjoint, representable, lausanne, is, homomorphisms, nobleman, irrespective,
# Nearest to most: grained, in, many, amigaos, trumped, are, correspondents, railways,
# Nearest to time: at, lombardi, gunpowder, calculated, leveraged, lieu, ajaigarh, halt,
# Nearest to bible: lengthwise, biblical, prophets, tanakh, atone, commentary, goode, mosque,
# Nearest to accepted: divergence, cordwainer, oligarchic, political, faqs, strafford, psychedelics, davison,
# Nearest to except: spend, vert, focussed, robust, can, kyd, if, goes,
# Nearest to orthodox: haughton, christian, err, fanzines, armada, hasdai, paleogeography, yunus,
# Nearest to bbc: rosencrantz, embarking, cnn, broadcasting, sunset, itv, newspapers, premiered,
# Nearest to dr: answering, karim, roeg, swordsman, appointment, hitchens, ugc, hbo,
# Nearest to something: enchantment, lorids, iterated, conversation, neurophysiological, conceptions, realize, broadcasts,
# Nearest to troops: violations, accede, tactics, carthage, bombardment, ripuarian, zoran, munitions,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0622 0.0909 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0691 0.0895 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0533 0.0891 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0700 0.0891 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0609 0.0894 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0551 0.0888 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0649 0.0892 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0679 0.0892 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0882 0.0888 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0781 0.0890 sec/batch
# Nearest to is: the, a, parentheses, anaximander, separable, prayer, all, miracles,
# Nearest to two: five, zero, three, nine, four, one, seven, december,
# Nearest to people: poorest, descendants, amphibians, homographs, lice, gediminas, population, emissaries,
# Nearest to united: affleck, comecon, seedy, jurors, nicaragua, loudly, npd, sharqi,
# Nearest to by: marrying, which, uninterrupted, as, stalled, remained, holborn, and,
# Nearest to an: lausanne, supernova, nobleman, ackroyd, disjoint, homomorphisms, deployed, is,
# Nearest to most: grained, in, many, correspondents, trumped, railways, amigaos, drains,
# Nearest to time: at, lombardi, halt, calculated, leveraged, hizbullah, ajaigarh, lieu,
# Nearest to bible: biblical, lengthwise, atone, tanakh, prophets, goode, commentary, mosque,
# Nearest to accepted: divergence, cordwainer, political, oligarchic, strafford, davison, claimant, faqs,
# Nearest to except: spend, robust, focussed, can, vert, backbench, passes, unsettled,
# Nearest to orthodox: christian, haughton, hasdai, err, fanzines, paleogeography, armada, scriptura,
# Nearest to bbc: rosencrantz, cnn, embarking, broadcasting, itv, sunset, terrestris, newspapers,
# Nearest to dr: answering, swordsman, roeg, hooper, accidental, karim, conjoined, ugc,
# Nearest to something: enchantment, lorids, conversation, gently, broadcasts, iterated, occidentalis, neurophysiological,
# Nearest to troops: violations, tactics, carthage, ripuarian, accede, azul, bombardment, zoran,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0679 0.0908 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0139 0.0901 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0490 0.0898 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0267 0.0904 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0668 0.0896 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1188 0.0896 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1390 0.0898 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0457 0.0896 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0369 0.0892 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0638 0.0885 sec/batch
# Nearest to is: a, the, parentheses, separable, langle, opts, unique, prayer,
# Nearest to two: five, zero, nine, four, three, one, seven, december,
# Nearest to people: poorest, descendants, population, gediminas, noir, amphibians, homographs, emissaries,
# Nearest to united: affleck, seedy, jurors, comecon, npd, nicaragua, sharqi, uphold,
# Nearest to by: marrying, uninterrupted, holborn, transshipment, which, icy, rendered, as,
# Nearest to an: lausanne, supernova, ackroyd, morel, rq, deployed, nobleman, homomorphisms,
# Nearest to most: grained, in, many, railways, amigaos, correspondents, anemone, trumped,
# Nearest to time: at, lombardi, calculated, colder, ajaigarh, haithabu, leveraged, when,
# Nearest to bible: lengthwise, biblical, atone, tanakh, goode, commentary, mosque, prophets,
# Nearest to accepted: cordwainer, divergence, davison, political, oligarchic, strafford, claimant, faqs,
# Nearest to except: spend, robust, can, focussed, backbench, risen, vert, if,
# Nearest to orthodox: err, haughton, fanzines, christian, hasdai, paleogeography, raeben, imbued,
# Nearest to bbc: rosencrantz, sunset, cnn, embarking, itv, terrestris, broadcasting, days,
# Nearest to dr: answering, jeeps, swordsman, karim, roeg, appointment, accidental, hooper,
# Nearest to something: enchantment, conversation, lorids, gently, neurophysiological, broadcasts, realize, know,
# Nearest to troops: violations, ripuarian, tactics, carthage, accede, bombardment, disaster, zoran,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9820 0.0909 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0465 0.0899 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0139 0.0897 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0255 0.0894 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0918 0.0889 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0600 0.0793 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0076 0.0894 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9746 0.0887 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0122 0.0887 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9796 0.0887 sec/batch
# Nearest to is: a, the, parentheses, prayer, anaximander, miracles, an, separable,
# Nearest to two: five, zero, nine, four, one, three, seven, six,
# Nearest to people: poorest, descendants, population, amphibians, homographs, emissaries, noir, bushmen,
# Nearest to united: affleck, seedy, jurors, comecon, sharqi, moulds, nicaragua, uphold,
# Nearest to by: marrying, holborn, uninterrupted, which, rendered, tunnels, icy, transshipment,
# Nearest to an: lausanne, nobleman, supernova, is, deployed, representable, morel, disjoint,
# Nearest to most: in, grained, many, amigaos, railways, correspondents, anemone, deniability,
# Nearest to time: at, lombardi, colder, sui, received, haithabu, lieu, gunpowder,
# Nearest to bible: lengthwise, biblical, atone, tanakh, goode, mosque, prophets, commentary,
# Nearest to accepted: divergence, oligarchic, cordwainer, davison, claimant, whoever, faqs, political,
# Nearest to except: spend, robust, can, passes, focussed, vert, if, kangaroos,
# Nearest to orthodox: err, haughton, fanzines, christian, armada, paleogeography, hasdai, imbued,
# Nearest to bbc: rosencrantz, sunset, cnn, day, days, terrestris, itv, embarking,
# Nearest to dr: answering, jeeps, karim, appointment, swordsman, accidental, intergovernmental, hitchens,
# Nearest to something: enchantment, conversation, lorids, realize, gently, occidentalis, know, iterated,
# Nearest to troops: ripuarian, violations, tactics, carthage, accede, zoran, bombardment, pickford,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9725 0.0897 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9711 0.0888 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0068 0.0888 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0061 0.0891 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0351 0.0902 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0311 0.0900 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9051 0.0899 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9529 0.0906 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9472 0.0900 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9999 0.0897 sec/batch
# Nearest to is: the, a, parentheses, an, all, of, in, from,
# Nearest to two: five, zero, four, three, nine, one, seven, six,
# Nearest to people: poorest, descendants, population, homographs, amphibians, lice, noir, gediminas,
# Nearest to united: affleck, seedy, jurors, comecon, sharqi, ryukyu, uphold, nicaragua,
# Nearest to by: which, rendered, marrying, uninterrupted, transshipment, holborn, called, the,
# Nearest to an: is, lausanne, supernova, rq, deployed, disjoint, nobleman, utf,
# Nearest to most: in, grained, many, amigaos, railways, deniability, effector, repressor,
# Nearest to time: at, lombardi, calculated, colder, haithabu, lieu, leveraged, when,
# Nearest to bible: lengthwise, biblical, tanakh, atone, goode, prophets, commentary, mosque,
# Nearest to accepted: divergence, claimant, oligarchic, cordwainer, davison, belonged, faqs, whoever,
# Nearest to except: spend, passes, robust, vert, kyd, risen, if, can,
# Nearest to orthodox: err, haughton, fanzines, armada, paleogeography, supplements, raeben, hasdai,
# Nearest to bbc: itv, cnn, rosencrantz, broadcasting, sunset, terrestris, embarking, day,
# Nearest to dr: answering, jeeps, karim, swordsman, accidental, appointment, ugc, hooper,
# Nearest to something: enchantment, conversation, gently, lorids, occidentalis, realize, iterated, dojo,
# Nearest to troops: ripuarian, violations, tactics, bombardment, pickford, zoran, carthage, accede,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0107 0.0911 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0074 0.0901 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9560 0.0899 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0330 0.0892 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0027 0.0891 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9576 0.0900 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9887 0.0899 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9812 0.0894 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9788 0.0893 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0102 0.0888 sec/batch
# Nearest to is: the, a, all, an, separable, parentheses, of, prayer,
# Nearest to two: five, zero, four, three, nine, one, seven, six,
# Nearest to people: homographs, poorest, descendants, noir, population, amphibians, lice, chios,
# Nearest to united: affleck, seedy, jurors, comecon, mcdermott, marley, sharqi, moulds,
# Nearest to by: which, marrying, as, called, uninterrupted, the, holborn, and,
# Nearest to an: is, supernova, lausanne, rq, morel, transhuman, nobleman, ackroyd,
# Nearest to most: in, grained, amigaos, many, correspondents, appropriated, filk, railways,
# Nearest to time: at, lombardi, calculated, leveraged, lieu, haithabu, benchmarks, broadcasters,
# Nearest to bible: lengthwise, biblical, tanakh, atone, goode, commentary, prophets, mosque,
# Nearest to accepted: divergence, oligarchic, cordwainer, claimant, faqs, psychedelics, davison, belonged,
# Nearest to except: spend, passes, can, vert, kyd, goes, visibly, risen,
# Nearest to orthodox: autocephalous, haughton, err, fanzines, paleogeography, armada, supplements, christian,
# Nearest to bbc: itv, rosencrantz, cnn, terrestris, sunset, broadcasting, day, embarking,
# Nearest to dr: answering, jeeps, ugc, accidental, karim, swordsman, roeg, hooper,
# Nearest to something: enchantment, conversation, gently, lorids, realize, occidentalis, iterated, orie,
# Nearest to troops: violations, ripuarian, pickford, bombardment, tactics, accede, carthage, zoran,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9885 0.0907 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9624 0.0895 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9941 0.0887 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0279 0.0893 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0207 0.0894 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0054 0.0887 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9745 0.0897 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9536 0.0903 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9990 0.0896 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0179 0.0903 sec/batch
# Nearest to is: a, the, an, in, of, prayer, to, consists,
# Nearest to two: five, zero, four, nine, three, one, seven, six,
# Nearest to people: poorest, descendants, homographs, population, noir, lice, amphibians, living,
# Nearest to united: affleck, jurors, seedy, kingdom, marley, comecon, sharqi, mcdermott,
# Nearest to by: which, and, the, as, marrying, called, transshipment, holborn,
# Nearest to an: is, lausanne, homomorphisms, of, in, on, to, utf,
# Nearest to most: in, many, grained, amigaos, appropriated, railways, anemone, correspondents,
# Nearest to time: at, calculated, superclasses, haithabu, objectives, metonic, leveraged, charitable,
# Nearest to bible: lengthwise, biblical, atone, tanakh, goode, prophets, commentary, mosque,
# Nearest to accepted: divergence, oligarchic, claimant, cordwainer, davison, faqs, belonged, strafford,
# Nearest to except: passes, spend, can, goes, robust, kangaroos, backbench, risen,
# Nearest to orthodox: autocephalous, supplements, fanzines, armada, haughton, err, paleogeography, lexis,
# Nearest to bbc: itv, rosencrantz, cnn, terrestris, sunset, day, broadcasting, hark,
# Nearest to dr: answering, jeeps, accidental, karim, swordsman, ugc, nlm, hooper,
# Nearest to something: conversation, enchantment, gently, realize, lorids, occidentalis, know, neurophysiological,
# Nearest to troops: violations, ripuarian, tactics, bombardment, pickford, accede, zoran, carthage,
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8002 0.0895 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8584 0.0898 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8655 0.0898 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8425 0.0901 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8575 0.0894 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9192 0.0893 sec/batch
# Nearest to is: a, the, of, in, an, from, be, for,
# Nearest to two: zero, five, one, four, three, nine, six, eight,
# Nearest to people: living, lice, twitching, births, descendants, who, dioxin, methodists,
# Nearest to united: kingdom, states, america, geffen, affleck, american, nations, moulds,
# Nearest to by: and, the, which, called, to, in, of, on,
# Nearest to an: a, is, in, on, of, which, for, to,
# Nearest to most: many, in, are, popular, early, amigaos, more, and,
# Nearest to time: at, haithabu, superclasses, metonic, product, home, a, colder,
# Nearest to bible: lengthwise, biblical, atone, tanakh, roach, goode, quux, chiropractic,
# Nearest to accepted: belonged, claimant, surveyed, canaries, chrismation, ev, cj, ptolemies,
# Nearest to except: passes, phrygian, mollymawks, spend, goes, prerequisite, only, gluons,
# Nearest to orthodox: eastern, autocephalous, guerin, lexis, afterburner, userbase, imperii, fanzines,
# Nearest to bbc: day, itv, broadcasting, stalks, listing, embarking, days, external,
# Nearest to dr: answering, nmt, nlm, hooper, jeeps, expressionists, appointment, swordsman,
# Nearest to something: lorids, realize, enchantment, neurophysiological, conversation, cole, octagonal, without,
# Nearest to troops: zoran, ripuarian, munitions, tactics, batter, azul, wilder, soldiers,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8448 0.0903 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8310 0.0893 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8272 0.0895 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8424 0.0895 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8746 0.0894 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8641 0.0891 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8719 0.0886 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8487 0.0890 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8670 0.0887 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8448 0.0896 sec/batch
# Nearest to is: a, the, of, in, an, this, from, as,
# Nearest to two: zero, five, one, three, four, nine, six, eight,
# Nearest to people: living, lice, twitching, births, methodists, who, descendants, guardians,
# Nearest to united: kingdom, states, america, nations, marley, geffen, adopted, american,
# Nearest to by: and, the, of, which, in, on, to, called,
# Nearest to an: a, is, of, in, on, which, to, for,
# Nearest to most: many, in, as, are, early, more, popular, tagore,
# Nearest to time: metonic, at, received, superclasses, were, colder, haithabu, cannonballs,
# Nearest to bible: lengthwise, biblical, atone, roach, tanakh, quux, goode, saleh,
# Nearest to accepted: belonged, claimant, surveyed, ev, cj, canaries, oligarchic, chrismation,
# Nearest to except: passes, mollymawks, gluons, phrygian, only, capacitors, prerequisite, hydrocarbons,
# Nearest to orthodox: autocephalous, eastern, lexis, guerin, afterburner, raeben, userbase, paleogeography,
# Nearest to bbc: day, itv, listing, stalks, broadcasting, days, external, cnn,
# Nearest to dr: answering, nmt, appointment, expressionists, hooper, nlm, jeeps, swordsman,
# Nearest to something: lorids, neurophysiological, realize, enchantment, conversation, without, enjoying, cole,
# Nearest to troops: ripuarian, zoran, tactics, batter, munitions, azul, soldiers, army,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8466 0.0901 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8625 0.0900 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8452 0.0900 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8442 0.0896 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8955 0.0899 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8251 0.0899 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9538 0.0891 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9063 0.0897 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9133 0.0893 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8123 0.0895 sec/batch
# Nearest to is: a, the, of, in, an, this, be, as,
# Nearest to two: zero, five, one, three, four, nine, eight, six,
# Nearest to people: living, births, lice, who, natives, dioxin, methodists, twitching,
# Nearest to united: states, kingdom, nations, america, affleck, geffen, american, marley,
# Nearest to by: and, the, in, of, as, called, on, to,
# Nearest to an: a, of, is, in, on, to, for, the,
# Nearest to most: in, many, as, are, early, to, and, the,
# Nearest to time: colder, metonic, at, cannonballs, attains, superclasses, haithabu, early,
# Nearest to bible: lengthwise, biblical, roach, tanakh, atone, quux, goode, chiropractic,
# Nearest to accepted: belonged, claimant, surveyed, cj, oligarchic, canaries, davison, nrc,
# Nearest to except: passes, mollymawks, gluons, shatz, phrygian, capacitors, desi, prerequisite,
# Nearest to orthodox: autocephalous, guerin, lexis, eastern, afterburner, raeben, userbase, fanzines,
# Nearest to bbc: day, itv, days, listing, broadcasting, stalks, external, embarking,
# Nearest to dr: answering, nmt, appointment, nlm, swordsman, expressionists, hooper, jeeps,
# Nearest to something: lorids, neurophysiological, realize, enchantment, enjoying, cole, conversation, occidentalis,
# Nearest to troops: ripuarian, zoran, tactics, munitions, azul, batter, soldiers, army,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7897 0.0900 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8677 0.0888 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7628 0.0895 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8633 0.0895 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8526 0.0889 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8472 0.0893 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9134 0.0431 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8238 0.0890 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8286 0.0889 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8166 0.0885 sec/batch
# Nearest to is: a, the, in, of, an, as, from, be,
# Nearest to two: five, zero, one, four, three, nine, eight, six,
# Nearest to people: living, lice, births, twitching, dioxin, who, essayists, natives,
# Nearest to united: states, kingdom, america, geffen, nations, affleck, american, marley,
# Nearest to by: and, the, of, in, called, to, from, on,
# Nearest to an: a, is, of, in, on, for, which, the,
# Nearest to most: many, in, early, are, as, has, popular, and,
# Nearest to time: metonic, colder, haithabu, at, early, attains, kristeva, course,
# Nearest to bible: lengthwise, biblical, roach, quux, tanakh, atone, goode, chiropractic,
# Nearest to accepted: belonged, claimant, surveyed, cited, canaries, eteocretan, ev, oligarchic,
# Nearest to except: passes, mollymawks, goes, phrygian, capacitors, gluons, visibly, desi,
# Nearest to orthodox: autocephalous, eastern, lexis, guerin, afterburner, raeben, congresswoman, err,
# Nearest to bbc: day, listing, days, itv, external, august, broadcasting, stalks,
# Nearest to dr: answering, appointment, nmt, nlm, swordsman, jeeps, hooper, expressionists,
# Nearest to something: lorids, realize, neurophysiological, enchantment, occidentalis, enjoying, conversation, cole,
# Nearest to troops: zoran, ripuarian, munitions, tactics, batter, azul, soldiers, yukon,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8321 0.0899 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8049 0.0895 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8353 0.0893 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7997 0.0888 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8421 0.0889 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8182 0.0894 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8959 0.0895 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7856 0.0901 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8134 0.0904 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8009 0.0900 sec/batch
# Nearest to is: the, a, of, in, an, be, for, as,
# Nearest to two: zero, five, one, four, three, nine, eight, six,
# Nearest to people: living, births, lice, who, dioxin, descendants, methodists, guardians,
# Nearest to united: states, kingdom, america, geffen, nations, affleck, prohibition, marley,
# Nearest to by: and, the, in, of, called, which, to, on,
# Nearest to an: a, is, of, in, which, on, for, the,
# Nearest to most: many, in, early, are, and, a, the, as,
# Nearest to time: at, metonic, haithabu, a, colder, attains, home, for,
# Nearest to bible: lengthwise, biblical, roach, tanakh, atone, quux, chiropractic, tufts,
# Nearest to accepted: belonged, claimant, surveyed, eteocretan, ptolemies, conciliar, cited, oligarchic,
# Nearest to except: passes, mollymawks, phrygian, capacitors, only, protestantism, gluons, desi,
# Nearest to orthodox: lexis, guerin, autocephalous, eastern, afterburner, userbase, iotation, err,
# Nearest to bbc: day, itv, external, broadcasting, listing, days, embarking, thursday,
# Nearest to dr: answering, nmt, nlm, swordsman, appointment, hooper, pashto, jeeps,
# Nearest to something: lorids, enchantment, realize, neurophysiological, occidentalis, conversation, enjoying, cole,
# Nearest to troops: zoran, ripuarian, munitions, tactics, batter, azul, yukon, soldiers,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7593 0.0905 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8068 0.0894 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8404 0.0895 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8061 0.0901 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8236 0.0893 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8737 0.0888 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8720 0.0893 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8359 0.0891 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8177 0.0893 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8392 0.0891 sec/batch
# Nearest to is: a, the, of, in, an, this, be, for,
# Nearest to two: zero, five, one, four, three, nine, eight, six,
# Nearest to people: living, births, lice, who, natives, population, methodists, dioxin,
# Nearest to united: states, kingdom, america, nations, geffen, adopted, american, virginia,
# Nearest to by: and, the, of, which, called, to, in, on,
# Nearest to an: a, is, in, of, on, for, which, the,
# Nearest to most: many, early, in, as, are, a, more, and,
# Nearest to time: at, a, colder, early, haithabu, metonic, home, course,
# Nearest to bible: lengthwise, biblical, roach, quux, atone, tanakh, tufts, chiropractic,
# Nearest to accepted: belonged, claimant, surveyed, cited, eteocretan, paleontologist, cj, canaries,
# Nearest to except: passes, mollymawks, only, phrygian, capacitors, gluons, both, visibly,
# Nearest to orthodox: eastern, autocephalous, lexis, guerin, afterburner, userbase, iotation, raeben,
# Nearest to bbc: day, itv, listing, broadcasting, days, embarking, thursday, external,
# Nearest to dr: answering, nmt, nlm, swordsman, expressionists, manipulate, hooper, ugc,
# Nearest to something: lorids, neurophysiological, realize, cole, enchantment, enjoying, without, occidentalis,
# Nearest to troops: zoran, ripuarian, munitions, tactics, azul, batter, soldiers, army,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8919 0.0903 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8184 0.0889 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8048 0.0889 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8167 0.0889 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8792 0.0883 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8530 0.0888 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8290 0.0884 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8235 0.0891 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8013 0.0902 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8230 0.0897 sec/batch
# Nearest to is: a, the, of, in, an, this, be, as,
# Nearest to two: zero, five, one, four, three, nine, eight, six,
# Nearest to people: living, who, births, population, guardians, natives, lice, dioxin,
# Nearest to united: states, kingdom, america, nations, geffen, britain, american, marley,
# Nearest to by: and, the, of, to, in, as, called, which,
# Nearest to an: a, is, of, in, the, on, for, to,
# Nearest to most: as, many, in, the, are, to, and, early,
# Nearest to time: at, metonic, a, course, colder, home, were, cannonballs,
# Nearest to bible: lengthwise, biblical, roach, atone, tanakh, zeal, quux, saleh,
# Nearest to accepted: belonged, cited, claimant, surveyed, eteocretan, argument, possess, unfortunately,
# Nearest to except: passes, mollymawks, phrygian, however, gluons, protestantism, only, both,
# Nearest to orthodox: eastern, autocephalous, lexis, guerin, iotation, afterburner, adapting, userbase,
# Nearest to bbc: day, itv, listing, days, thursday, embarking, broadcasting, external,
# Nearest to dr: answering, nmt, swordsman, nlm, manipulate, expressionists, appointment, ugc,
# Nearest to something: lorids, realize, neurophysiological, cole, without, enjoying, occidentalis, conversation,
# Nearest to troops: zoran, ripuarian, tactics, azul, munitions, soldiers, army, batter,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8579 0.0910 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8140 0.0896 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9248 0.0893 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8921 0.0889 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8677 0.0896 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8626 0.0896 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8019 0.0888 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8312 0.0887 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7477 0.0889 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8992 0.0898 sec/batch
# Nearest to is: a, the, in, of, an, as, this, from,
# Nearest to two: zero, one, five, four, nine, three, eight, six,
# Nearest to people: living, births, natives, population, methodists, who, deaths, twitching,
# Nearest to united: states, kingdom, america, nations, geffen, virginia, britain, affleck,
# Nearest to by: and, the, in, of, as, which, called, to,
# Nearest to an: a, is, in, of, the, for, which, on,
# Nearest to most: as, many, in, the, early, and, were, a,
# Nearest to time: at, haithabu, early, metonic, a, colder, cannonballs, were,
# Nearest to bible: lengthwise, biblical, roach, quux, tanakh, atone, saleh, tufts,
# Nearest to accepted: belonged, claimant, cited, surveyed, davison, lanzarote, unfortunately, chimpanzee,
# Nearest to except: passes, mollymawks, phrygian, gluons, desi, capacitors, visibly, only,
# Nearest to orthodox: lexis, eastern, guerin, autocephalous, iotation, afterburner, raeben, adapting,
# Nearest to bbc: day, listing, days, itv, external, diena, thursday, august,
# Nearest to dr: answering, nmt, nlm, premature, manipulate, expressionists, swordsman, appointment,
# Nearest to something: lorids, neurophysiological, realize, cole, enjoying, enchantment, without, occidentalis,
# Nearest to troops: zoran, ripuarian, soldiers, tactics, munitions, azul, forces, army,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8262 0.0900 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8169 0.0889 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
